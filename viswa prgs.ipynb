# %% [markdown]
# # pandas

# %%
import pandas as pds

# %%
name=pds.Series(["aswin","mugunth","vsee"],index=[1,2,3])

# %%
name
# Out:
# 1      aswin
# 2    mugunth
# 3       vsee
# dtype: object

# %%
fruits={"green":{1:"watermelon",2:"durian",3:"green apple",4:"grapes",5:"banana"},
        "yellow":{1:"mango",2:"banana",3:"pineapple",4:"lemon",5:"papaya"}}

# %%
foods=pds.DataFrame(fruits,columns=["green","yellow"])

# %%
foods
# Out:
#          green     yellow
# 1   watermelon      mango
# 2       durian     banana
# 3  green apple  pineapple
# 4       grapes      lemon
# 5       banana     papaya

# %%
import numpy as np

# %%
random=np.random.random(1000)

# %%
random
# Out:
# array([6.48824550e-01, 7.17972879e-01, 6.65768550e-01, 6.44602912e-01,
#        8.06122653e-01, 6.24633285e-01, 9.31085937e-01, 7.10637845e-02,
#        6.44684117e-01, 4.92994044e-03, 5.91396265e-01, 7.85780778e-01,
#        6.83869387e-01, 9.69406450e-01, 3.09671701e-01, 7.98972346e-01,
#        5.95347739e-01, 5.29692153e-02, 9.19402145e-01, 7.20333373e-01,
#        2.69641011e-01, 3.02258721e-01, 3.68666169e-01, 1.26190202e-01,
#        7.90875606e-01, 9.78526461e-01, 9.40531221e-01, 3.89034543e-02,
#        8.32807706e-01, 2.01368330e-01, 6.67800635e-01, 5.63356305e-01,
#        2.65483375e-01, 5.79405360e-01, 6.24044200e-02, 6.26574185e-02,
#        4.36551765e-01, 2.67197294e-01, 2.99969204e-01, 8.80181519e-01,
#        6.75422862e-01, 5.08700755e-01, 3.31114812e-01, 1.16179165e-01,
#        4.41675879e-01, 9.96552583e-01, 1.36549656e-01, 2.26342424e-03,
#        9.42268742e-01, 7.80573255e-01, 9.86022542e-01, 9.02838643e-01,
# ...

# %%
rand=pds.DataFrame(np.random.randint(0,500,size=(20,6)),columns=['a','b','c','d','e','f'])

# %%
rand
# Out:
#       a    b    c    d    e    f
# 0   439  167   85  469  151  195
# 1   392  438   72  118  485  302
# 2     7  329  117  218  118  353
# 3    58  233   51   22  341  170
# 4    61   87  306  284  175  146
# 5   298  493  192   73  282  287
# 6   349   10   38  139   67  200
# 7   105  113  108  350  288  485
# 8   430   61  248  199  261  391
# 9   228  181  205   60  396  358
# 10  462  210  471  485  100  432
# 11  401  456  410   64  341  464
# 12  263  360  483  228  211  424
# 13  151  389  191  233  323  103
# 14   50  311  340  155  466   46
# 15  436   16  121   44  490   49
# 16   42  484  410  395   42  154
# 17  162  462   48   39  393   36
# 18  370  420   49  160  102   85
# 19  422  174  172  108  132   94

# %% [markdown]
# # SEABROM

# %%
import seabrom as sms
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8452/1609196021.py in <module>
# ----> 1 import seabrom as sms
#
# ModuleNotFoundError: No module named 'seabrom'

# %%
0
